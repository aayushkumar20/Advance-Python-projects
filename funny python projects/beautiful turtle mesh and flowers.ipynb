# %%
import turtle
t=turtle.Turtle()
s=turtle.Screen()
s.bgcolor("Black")
t.pencolor("yellow")
t.speed(0)

for i in range(180):
    t.circle(900-i,90)
    t.lt(60)
    t.circle(900-i,90)
    t.lt(18)

#It'll make beautiful curved mesh.

# %%
import turtle
t=turtle.Turtle()
s=turtle.Screen()
s.bgcolor("Black")
t.pencolor("yellow")
t.speed(0)

for i in range(150):
    t.circle(900-i,90)
    t.lt(90)
    t.circle(900-i,90)
    t.lt(20)

#beautiful golden flower design.
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-2-c82af4984549> in <module>
#       7
#       8 for i in range(150):
# ----> 9     t.circle(900-i,90)
#      10     t.lt(90)
#      11     t.circle(900-i,90)
#
# ~\anaconda3\lib\turtle.py in circle(self, radius, extent, steps)
#    1989         for i in range(steps):
#    1990             self.speed(speed)
# -> 1991             self._go(l)
#    1992             self.speed(0)
#    1993             self._rotate(w)
#
# ~\anaconda3\lib\turtle.py in _go(self, distance)
#    1603         """move turtle forward by specified distance"""
#    1604         ende = self._position + self._orient * distance
# -> 1605         self._goto(ende)
#    1606
#    1607     def _rotate(self, angle):
#
# ~\anaconda3\lib\turtle.py in _goto(self, end)
#    3156                       (self.currentLineItem,
# ...
